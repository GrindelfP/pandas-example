# %%
import pandas as pd
from soupsieve.util import lower
import matplotlib

# %%
df = pd.read_csv('data/2019.csv') # reading the source file

# %%
df.head() # shows the first 5 rows of the data table
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df.tail() # shows the last 5 rows of the data table
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 151       0.217                      0.411
# ...

# %%
display(df) # shows the whole data table (it is truncated depending on settings of the notebook)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df.shape # shows the number of rows and columns
# Out:
# (156, 9)

# %%
df.shape[0] # shows the number of rows
# Out:
# 156

# %%
df.shape[1] # shows the number of columns
# Out:
# 9

# %%
df.rename(columns={'Overall rank': 'Место в рейтинге',
                   'Country or region': 'Страна или регион',
                   'Score': 'Баллы', 'GDP per capita': 'ВВП на душу населения',
                   'Social support': 'Социальная поддержка',
                   'Healthy life expectancy': 'Ожидаемая продолжительность здоровой жизни',
                   'Freedom to make life choices': 'Свобода жизненных выборов',
                   'Generosity': 'Щедрость', 'Perceptions of corruption': 'Восприятие коррупции'},
          inplace=True) # renames the column headers as specified
df.head()
# Out:
#    Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 0                 1           Finland  7.769                  1.340
# 1                 2           Denmark  7.600                  1.383
# 2                 3            Norway  7.554                  1.488
# 3                 4           Iceland  7.494                  1.380
# 4                 5       Netherlands  7.488                  1.396
#
#    Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 0                 1.587                                       0.986
# 1                 1.573                                       0.996
# 2                 1.582                                       1.028
# 3                 1.624                                       1.026
# 4                 1.522                                       0.999
#
#    Свобода жизненных выборов  Щедрость  Восприятие коррупции
# 0                      0.596     0.153                 0.393
# ...

# %%
df.describe() # shows descriptive statistics for all numeric columns; from docs:
# Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset's distribution, excluding NaN values.
# Out:
#        Место в рейтинге       Баллы  ВВП на душу населения  \
# count        156.000000  156.000000             156.000000
# mean          78.500000    5.407096               0.905147
# std           45.177428    1.113120               0.398389
# min            1.000000    2.853000               0.000000
# 25%           39.750000    4.544500               0.602750
# 50%           78.500000    5.379500               0.960000
# 75%          117.250000    6.184500               1.232500
# max          156.000000    7.769000               1.684000
#
#        Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# count            156.000000                                  156.000000
# mean               1.208814                                    0.725244
# std                0.299191                                    0.242124
# min                0.000000                                    0.000000
# ...

# %%
df.info() # shows info about the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Место в рейтинге                            156 non-null    int64
#  1   Страна или регион                           156 non-null    object
#  2   Баллы                                       156 non-null    float64
#  3   ВВП на душу населения                       156 non-null    float64
#  4   Социальная поддержка                        156 non-null    float64
#  5   Ожидаемая продолжительность здоровой жизни  156 non-null    float64
#  6   Свобода жизненных выборов                   156 non-null    float64
#  7   Щедрость                                    156 non-null    float64
#  8   Восприятие коррупции                        156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
data_new = df[['Место в рейтинге',
               'Ожидаемая продолжительность здоровой жизни']] # creates a new data frame with only two columns out of the original one

# %%
df.loc[:, 'Место в рейтинге':'Социальная поддержка'] # truncates dataframe within defined columns
# Out:
#      Место в рейтинге         Страна или регион  Баллы  ВВП на душу населения  \
# 0                   1                   Finland  7.769                  1.340
# 1                   2                   Denmark  7.600                  1.383
# 2                   3                    Norway  7.554                  1.488
# 3                   4                   Iceland  7.494                  1.380
# 4                   5               Netherlands  7.488                  1.396
# ..                ...                       ...    ...                    ...
# 151               152                    Rwanda  3.334                  0.359
# 152               153                  Tanzania  3.231                  0.476
# 153               154               Afghanistan  3.203                  0.350
# 154               155  Central African Republic  3.083                  0.026
# 155               156               South Sudan  2.853                  0.306
#
#      Социальная поддержка
# ...

# %%
df.iloc[0:100, 0:5] # truncates dataframe within defined rows and columns with following params: first - interval of rows, second - interval of columns
# Out:
#     Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 0                  1           Finland  7.769                  1.340
# 1                  2           Denmark  7.600                  1.383
# 2                  3            Norway  7.554                  1.488
# 3                  4           Iceland  7.494                  1.380
# 4                  5       Netherlands  7.488                  1.396
# ..               ...               ...    ...                    ...
# 95                96          Cameroon  5.044                  0.549
# 96                97          Bulgaria  5.011                  1.092
# 97                98             Ghana  4.996                  0.611
# 98                99       Ivory Coast  4.944                  0.569
# 99               100             Nepal  4.913                  0.446
#
#     Социальная поддержка
# 0                  1.587
# 1                  1.573
# 2                  1.582
# 3                  1.624
# ...

# %%
df['Баллы'].tolist() # converts a column to a list
# Out:
# [7.769,
#  7.6,
#  7.554,
#  7.494,
#  7.488,
#  7.48,
#  7.343,
#  7.307,
#  7.278,
#  7.246,
#  7.228,
#  7.167,
#  7.139,
#  7.09,
#  7.054,
#  7.021,
#  6.985,
#  6.923,
#  6.892,
#  6.852,
#  6.825,
#  6.726,
#  6.595,
#  6.592,
#  6.446,
#  6.444,
#  6.436,
#  6.375,
#  6.374,
#  6.354,
#  6.321,
#  6.3,
#  6.293,
#  6.262,
#  6.253,
#  6.223,
#  6.199,
#  6.198,
#  6.192,
#  6.182,
#  6.174,
#  6.149,
#  6.125,
#  6.118,
#  6.105,
#  6.1,
#  6.086,
#  6.07,
#  6.046,
#  6.028,
#  6.021,
#  6.008,
#  5.94,
#  5.895,
#  5.893,
#  5.89,
#  5.888,
#  5.886,
#  5.86,
#  5.809,
#  5.779,
#  5.758,
#  5.743,
#  5.718,
#  5.697,
#  5.693,
#  5.653,
#  5.648,
#  5.631,
#  5.603,
#  5.529,
#  5.525,
#  5.523,
#  5.467,
#  5.432,
#  5.43,
#  5.425,
#  5.386,
#  5.373,
#  5.339,
#  5.323,
#  5.287,
#  5.285,
#  5.274,
#  5.265,
#  5.261,
#  5.247,
#  5.211,
#  5.208,
#  5.208,
#  5.197,
#  5.192,
#  5.191,
#  5.175,
#  5.082,
#  5.044,
#  5.011,
#  4.996,
#  4.944,
#  4.913,
#  4.906,
# ...

# %%
df.columns.tolist() # converts column headers to a list
# Out:
# ['Место в рейтинге',
#  'Страна или регион',
#  'Баллы',
#  'ВВП на душу населения',
#  'Социальная поддержка',
#  'Ожидаемая продолжительность здоровой жизни',
#  'Свобода жизненных выборов',
#  'Щедрость',
#  'Восприятие коррупции']

# %%
df['Сумма ВВП и соцподдержки'] = df['ВВП на душу населения'] + df['Социальная поддержка'] # creates a new column with the sum of two existing columns

# %%
df.head()
# Out:
#    Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 0                 1           Finland  7.769                  1.340
# 1                 2           Denmark  7.600                  1.383
# 2                 3            Norway  7.554                  1.488
# 3                 4           Iceland  7.494                  1.380
# 4                 5       Netherlands  7.488                  1.396
#
#    Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 0                 1.587                                       0.986
# 1                 1.573                                       0.996
# 2                 1.582                                       1.028
# 3                 1.624                                       1.026
# 4                 1.522                                       0.999
#
#    Свобода жизненных выборов  Щедрость  Восприятие коррупции  Сумма  \
# 0                      0.596     0.153                 0.393  2.927
# ...

# %%
new_row = {'Место в рейтинге': 100,
           'Страна или регион': 'Country',
           'Баллы': 100}
df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True) # concatenation with a new row

# %%
df = pd.concat([df, pd.DataFrame([df.sum(axis=0)])], ignore_index=True) # concat with a line with sums of all columns

# %%
df = df.drop(['Сумма ВВП и соцподдержки'], axis=1) # removing the column (if axis=1 then columns)

# %%
df.head()
# Out:
#    Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 0                 1           Finland  7.769                  1.340
# 1                 2           Denmark  7.600                  1.383
# 2                 3            Norway  7.554                  1.488
# 3                 4           Iceland  7.494                  1.380
# 4                 5       Netherlands  7.488                  1.396
#
#    Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 0                 1.587                                       0.986
# 1                 1.573                                       0.996
# 2                 1.582                                       1.028
# 3                 1.624                                       1.026
# 4                 1.522                                       0.999
#
#    Свобода жизненных выборов  Щедрость  Восприятие коррупции
# 0                      0.596     0.153                 0.393
# ...

# %%
df = df.drop(df.shape[0] - 1, axis=0) # removing the last row (if axis=0 then rows)

# %%
df.tail()
# Out:
#      Место в рейтинге         Страна или регион    Баллы  \
# 152               153                  Tanzania    3.231
# 153               154               Afghanistan    3.203
# 154               155  Central African Republic    3.083
# 155               156               South Sudan    2.853
# 156               100                   Country  100.000
#
#      ВВП на душу населения  Социальная поддержка  \
# 152                  0.476                 0.885
# 153                  0.350                 0.517
# 154                  0.026                 0.000
# 155                  0.306                 0.575
# 156                    NaN                   NaN
#
#      Ожидаемая продолжительность здоровой жизни  Свобода жизненных выборов  \
# 152                                       0.499                      0.417
# 153                                       0.361                      0.000
# 154                                       0.105                      0.225
# ...

# %%
df_copied = df.copy() # copying the data frame

# %%
df_copied.head()
# Out:
#    Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 0                 1           Finland  7.769                  1.340
# 1                 2           Denmark  7.600                  1.383
# 2                 3            Norway  7.554                  1.488
# 3                 4           Iceland  7.494                  1.380
# 4                 5       Netherlands  7.488                  1.396
#
#    Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 0                 1.587                                       0.986
# 1                 1.573                                       0.996
# 2                 1.582                                       1.028
# 3                 1.624                                       1.026
# 4                 1.522                                       0.999
#
#    Свобода жизненных выборов  Щедрость  Восприятие коррупции
# 0                      0.596     0.153                 0.393
# ...

# %%
df['Страна или регион'].unique() # returns unique values of the specified column
# Out:
# array(['Finland', 'Denmark', 'Norway', 'Iceland', 'Netherlands',
#        'Switzerland', 'Sweden', 'New Zealand', 'Canada', 'Austria',
#        'Australia', 'Costa Rica', 'Israel', 'Luxembourg',
#        'United Kingdom', 'Ireland', 'Germany', 'Belgium', 'United States',
#        'Czech Republic', 'United Arab Emirates', 'Malta', 'Mexico',
#        'France', 'Taiwan', 'Chile', 'Guatemala', 'Saudi Arabia', 'Qatar',
#        'Spain', 'Panama', 'Brazil', 'Uruguay', 'Singapore', 'El Salvador',
#        'Italy', 'Bahrain', 'Slovakia', 'Trinidad & Tobago', 'Poland',
#        'Uzbekistan', 'Lithuania', 'Colombia', 'Slovenia', 'Nicaragua',
#        'Kosovo', 'Argentina', 'Romania', 'Cyprus', 'Ecuador', 'Kuwait',
#        'Thailand', 'Latvia', 'South Korea', 'Estonia', 'Jamaica',
#        'Mauritius', 'Japan', 'Honduras', 'Kazakhstan', 'Bolivia',
#        'Hungary', 'Paraguay', 'Northern Cyprus', 'Peru', 'Portugal',
#        'Pakistan', 'Russia', 'Philippines', 'Serbia', 'Moldova', 'Libya',
# ...

# %%
len(df['Страна или регион'].unique())
# Out:
# 157

# %%
df['Страна или регион'].value_counts() # returns number of unique values of the specified column
# Out:
# Страна или регион
# Finland                1
# Cambodia               1
# Benin                  1
# Congo (Brazzaville)    1
# Gabon                  1
#                       ..
# South Korea            1
# Estonia                1
# Jamaica                1
# Mauritius              1
# Country                1
# Name: count, Length: 157, dtype: int64

# %%
df['Баллы_new'] = round(df['Баллы']) # creates a new column with rounded values of the specified column

# %%
df.groupby('Баллы_new').count() # groups the data frame by the specified column and counts the number of rows in each group
# Out:
#            Место в рейтинге  Страна или регион  Баллы  ВВП на душу населения  \
# Баллы_new
# 3.0                       9                  9      9                      9
# 4.0                      26                 26     26                     26
# 5.0                      48                 48     48                     48
# 6.0                      49                 49     49                     49
# 7.0                      21                 21     21                     21
# 8.0                       3                  3      3                      3
# 100.0                     1                  1      1                      0
#
#            Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# Баллы_new
# 3.0                           9                                           9
# 4.0                          26                                          26
# 5.0                          48                                          48
# ...

# %%
df.groupby('Баллы_new').sum() # groups the data frame by the specified column and sums the values of each group
# Out:
#            Место в рейтинге  \
# Баллы_new
# 3.0                    1368
# 4.0                    3497
# 5.0                    4680
# 6.0                    2401
# 7.0                     294
# 8.0                       6
# 100.0                   100
#
#                                            Страна или регион    Баллы  \
# Баллы_new
# 3.0        BotswanaSyriaMalawiYemenRwandaTanzaniaAfghanis...   29.444
# 4.0        MauritaniaMozambiqueTunisiaBangladeshIraqCongo...  108.678
# 5.0        TajikistanCroatiaHong KongDominican RepublicBo...  239.294
# 6.0        TaiwanChileGuatemalaSaudi ArabiaQatarSpainPana...  294.443
# 7.0        IcelandNetherlandsSwitzerlandSwedenNew Zealand...  148.725
# 8.0                                     FinlandDenmarkNorway   22.923
# 100.0                                                Country  100.000
#
#            ВВП на душу населения  Социальная поддержка  \
# Баллы_new
# 3.0                        3.655                 5.934
# ...

# %%
# df.groupby('Баллы_new').mean() TODO: fix
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Programming/my/python/pandas-example/venv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~/Programming/my/python/pandas-example/venv/lib/python3.9/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/Programming/my/python/pandas-example/venv/lib/python3.9/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %%
# df.groupby('Баллы_new').median() TODO: fix
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Programming/my/python/pandas-example/venv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~/Programming/my/python/pandas-example/venv/lib/python3.9/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/Programming/my/python/pandas-example/venv/lib/python3.9/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %%
df_agg = df.groupby('Баллы_new').agg({
    'Баллы_new': 'count',
    'Баллы_new': 'sum',
    'Баллы_new': 'mean',
    'Баллы_new': 'median'
}) #

# %%
df['ВВП_new'] = round(df['ВВП на душу населения'])

# %%
pd.pivot_table(df,
               index=['Баллы_new'],
               columns=['ВВП_new'],
               values='Социальная поддержка',
               aggfunc='mean') # creates a pivot table with the specified params
# Out:
# ВВП_new         0.0       1.0     2.0
# Баллы_new
# 3.0        0.630143  0.761500     NaN
# 4.0        0.900667  1.083818     NaN
# 5.0        0.910111  1.172256     NaN
# 6.0             NaN  1.374478  1.3650
# 7.0             NaN  1.497263  1.3945
# 8.0             NaN  1.580667     NaN

# %%
df.sort_values(by='ВВП на душу населения').head()
# Out:
#      Место в рейтинге         Страна или регион  Баллы  ВВП на душу населения  \
# 111               112                   Somalia  4.668                  0.000
# 154               155  Central African Republic  3.083                  0.026
# 144               145                   Burundi  3.775                  0.046
# 140               141                   Liberia  3.975                  0.073
# 126               127          Congo (Kinshasa)  4.418                  0.094
#
#      Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 111                 0.698                                       0.268
# 154                 0.000                                       0.105
# 144                 0.447                                       0.380
# 140                 0.922                                       0.443
# 126                 1.125                                       0.357
#
# ...

# %%
df.sort_values(by='ВВП на душу населения', ascending=False).head()
# Out:
#     Место в рейтинге     Страна или регион  Баллы  ВВП на душу населения  \
# 28                29                 Qatar  6.374                  1.684
# 13                14            Luxembourg  7.090                  1.609
# 33                34             Singapore  6.262                  1.572
# 20                21  United Arab Emirates  6.825                  1.503
# 50                51                Kuwait  6.021                  1.500
#
#     Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 28                 1.313                                       0.871
# 13                 1.479                                       1.012
# 33                 1.463                                       1.141
# 20                 1.310                                       0.825
# 50                 1.319                                       0.808
#
#     Свобода жизненных выборов  Щедрость  Восприятие коррупции  Баллы_new  \
# ...

# %%
df.sort_values(by='ВВП на душу населения', ascending=True).head()
# Out:
#      Место в рейтинге         Страна или регион  Баллы  ВВП на душу населения  \
# 111               112                   Somalia  4.668                  0.000
# 154               155  Central African Republic  3.083                  0.026
# 144               145                   Burundi  3.775                  0.046
# 140               141                   Liberia  3.975                  0.073
# 126               127          Congo (Kinshasa)  4.418                  0.094
#
#      Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 111                 0.698                                       0.268
# 154                 0.000                                       0.105
# 144                 0.447                                       0.380
# 140                 0.922                                       0.443
# 126                 1.125                                       0.357
#
# ...

# %%
df[df['Страна или регион'] == 'Norway'] # filtering the data frame by the specified value of the specified column
# Out:
#    Место в рейтинге Страна или регион  Баллы  ВВП на душу населения  \
# 2                 3            Norway  7.554                  1.488
#
#    Социальная поддержка  Ожидаемая продолжительность здоровой жизни  \
# 2                 1.582                                       1.028
#
#    Свобода жизненных выборов  Щедрость  Восприятие коррупции  Баллы_new  \
# 2                      0.603     0.271                 0.341        8.0
#
#    ВВП_new
# 2      1.0

# %%
df[df['Ожидаемая продолжительность здоровой жизни'] > 1] # filtering the data frame by the specified condition
# Out:
#     Unnamed: 0.1  Unnamed: 0  Место в рейтинге Страна или регион  Баллы  \
# 2            2.0         2.0                 3            Norway  7.554
# 3            3.0         3.0                 4           Iceland  7.494
# 5            5.0         5.0                 6       Switzerland  7.480
# 6            6.0         6.0                 7            Sweden  7.343
# 7            7.0         7.0                 8       New Zealand  7.307
# 8            8.0         8.0                 9            Canada  7.278
# 9            9.0         9.0                10           Austria  7.246
# 10          10.0        10.0                11         Australia  7.228
# 12          12.0        12.0                13            Israel  7.139
# 13          13.0        13.0                14        Luxembourg  7.090
# 23          23.0        23.0                24            France  6.592
# 29          29.0        29.0                30             Spain  6.354
# ...

# %%
df[df['Страна или регион'].str.startswith('F')] # filtering the data frame by the specified condition
# Out:
#     Unnamed: 0.1  Unnamed: 0  Место в рейтинге Страна или регион  Баллы  \
# 0            0.0         0.0                 1           Finland  7.769
# 23          23.0        23.0                24            France  6.592
#
#     ВВП на душу населения  Социальная поддержка  \
# 0                   1.340                 1.587
# 23                  1.324                 1.472
#
#     Ожидаемая продолжительность здоровой жизни  Свобода жизненных выборов  \
# 0                                        0.986                      0.596
# 23                                       1.045                      0.436
#
#     Щедрость  Восприятие коррупции  Баллы_new  ВВП_new
# 0      0.153                 0.393        8.0      1.0
# 23     0.111                 0.183        7.0      1.0

# %%
df[(df['ВВП на душу населения'] > 1) & (df['Социальная поддержка'] > 1.5)] # filtering the data frame by the specified condition
# Out:
#     Unnamed: 0.1  Unnamed: 0  Место в рейтинге Страна или регион  Баллы  \
# 0            0.0         0.0                 1           Finland  7.769
# 1            1.0         1.0                 2           Denmark  7.600
# 2            2.0         2.0                 3            Norway  7.554
# 3            3.0         3.0                 4           Iceland  7.494
# 4            4.0         4.0                 5       Netherlands  7.488
# 5            5.0         5.0                 6       Switzerland  7.480
# 7            7.0         7.0                 8       New Zealand  7.307
# 8            8.0         8.0                 9            Canada  7.278
# 10          10.0        10.0                11         Australia  7.228
# 14          14.0        14.0                15    United Kingdom  7.054
# 15          15.0        15.0                16           Ireland  7.021
# 17          17.0        17.0                18           Belgium  6.923
# ...

# %%
def my_lower(row):
    return row.lower()
df['Страна или регион'].apply(my_lower) # applying some function to the specified column
# Out:
# 0                       finland
# 1                       denmark
# 2                        norway
# 3                       iceland
# 4                   netherlands
#                  ...
# 152                    tanzania
# 153                 afghanistan
# 154    central african republic
# 155                 south sudan
# 156                     country
# Name: Страна или регион, Length: 157, dtype: object

# %%
df_copied = df.copy()
df_copied.drop_duplicates(subset = ['ВВП_new', 'Баллы_new']) # removes duplicates of the specified columns and removes the duplicates' rows
# Out:
#      Место в рейтинге Страна или регион    Баллы  ВВП на душу населения  \
# 0                   1           Finland    7.769                  1.340
# 3                   4           Iceland    7.494                  1.380
# 13                 14        Luxembourg    7.090                  1.609
# 24                 25            Taiwan    6.446                  1.368
# 28                 29             Qatar    6.374                  1.684
# 73                 74        Tajikistan    5.467                  0.493
# 74                 75           Croatia    5.432                  1.155
# 121               122        Mauritania    4.490                  0.570
# 122               123        Mozambique    4.466                  0.204
# 147               148          Botswana    3.488                  1.041
# 149               150            Malawi    3.410                  0.191
# 156               100           Country  100.000                    NaN
#
# ...

# %%
df_copied.drop_duplicates(subset = ['ВВП_new', 'Баллы_new'], inplace = True) # removes duplicates of the specified columns and replaces duplicates with blanks

# %%
df_copied
# Out:
#      Место в рейтинге         Страна или регион    Баллы  \
# 0                   1                   Finland    7.769
# 1                   2                   Denmark    7.600
# 2                   3                    Norway    7.554
# 3                   4                   Iceland    7.494
# 4                   5               Netherlands    7.488
# ..                ...                       ...      ...
# 152               153                  Tanzania    3.231
# 153               154               Afghanistan    3.203
# 154               155  Central African Republic    3.083
# 155               156               South Sudan    2.853
# 156               100                   Country  100.000
#
#      ВВП на душу населения  Социальная поддержка  \
# 0                    1.340                 1.587
# 1                    1.383                 1.573
# 2                    1.488                 1.582
# 3                    1.380                 1.624
# ...

# %%
df_copied.fillna(0) # replaces NaN values with 0
# Out:
#      Место в рейтинге         Страна или регион    Баллы  \
# 0                   1                   Finland    7.769
# 1                   2                   Denmark    7.600
# 2                   3                    Norway    7.554
# 3                   4                   Iceland    7.494
# 4                   5               Netherlands    7.488
# ..                ...                       ...      ...
# 152               153                  Tanzania    3.231
# 153               154               Afghanistan    3.203
# 154               155  Central African Republic    3.083
# 155               156               South Sudan    2.853
# 156               100                   Country  100.000
#
#      ВВП на душу населения  Социальная поддержка  \
# 0                    1.340                 1.587
# 1                    1.383                 1.573
# 2                    1.488                 1.582
# 3                    1.380                 1.624
# ...

# %%
df_copied.dropna() # removes rows with NaN values
# Out:
#      Место в рейтинге         Страна или регион  Баллы  ВВП на душу населения  \
# 0                   1                   Finland  7.769                  1.340
# 1                   2                   Denmark  7.600                  1.383
# 2                   3                    Norway  7.554                  1.488
# 3                   4                   Iceland  7.494                  1.380
# 4                   5               Netherlands  7.488                  1.396
# ..                ...                       ...    ...                    ...
# 151               152                    Rwanda  3.334                  0.359
# 152               153                  Tanzania  3.231                  0.476
# 153               154               Afghanistan  3.203                  0.350
# 154               155  Central African Republic  3.083                  0.026
# 155               156               South Sudan  2.853                  0.306
#
# ...

# %%
df.plot(x = 'Место в рейтинге', y = 'ВВП на душу населения')
# Out:
# <Axes: xlabel='Место в рейтинге'>

# %%
df.plot.hist(x = 'Место в рейтинге', y = 'ВВП на душу населения')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.to_csv('data/2019.csv')
